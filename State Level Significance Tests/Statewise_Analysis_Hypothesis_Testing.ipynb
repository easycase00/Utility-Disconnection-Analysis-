# %%
import pandas as pd

df = pd.read_csv("C:/Users/gokul/Downloads/hard_fix_september_11_2024.csv")

# Filter the dataset for years 2018 to 2022
filtered_df = df[(df['Year'] >= 2018) & (df['Year'] <= 2022)]

# Group by State and check if each state has data for all years from 2018 to 2022
years_range = set(range(2018, 2023))
states_with_complete_data = (
    filtered_df.groupby('State')['Year']
    .apply(set)  
    .apply(lambda years: years_range.issubset(years))  
    .loc[lambda x: x]  
    .index.tolist()  
)

print("States with data from 2018 to 2022:")
print(states_with_complete_data)
# Out:
# States with data from 2018 to 2022:
# ['Alabama', 'California', 'Colorado', 'Connecticut', 'Florida', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Louisiana', 'Maine', 'Maryland', 'Michigan', 'Minnesota', 'Missouri', 'New Hampshire', 'New Jersey', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Rhode Island', 'South Carolina', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'Washington, D.C.', 'Wisconsin']

# %%
states_with_complete_data = [
    'Alabama', 'California', 'Colorado', 'Connecticut', 'Florida', 'Hawaii', 'Idaho', 'Illinois', 
    'Indiana', 'Iowa', 'Louisiana', 'Maine', 'Maryland', 'Michigan', 'Minnesota', 'Missouri', 
    'New Hampshire', 'New Jersey', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 
    'Oklahoma', 'Oregon', 'Rhode Island', 'South Carolina', 'Texas', 'Utah', 'Vermont', 
    'Virginia', 'Washington', 'Washington, D.C.', 'Wisconsin']

# Filter the dataset for the specified states and years
filtered_df2 = df[
    (df['State'].isin(states_with_complete_data)) &  
    (df['Year'] >= 2018) & (df['Year'] <= 2022)]

print(filtered_df2.head())
# Out:
#        State    Utility Name       Utility Type Service Type    Year  \
# 96   Alabama  City of Dothan  Municipal Utility     Electric  2018.0
# 97   Alabama  City of Dothan  Municipal Utility     Electric  2018.0
# 98   Alabama  City of Dothan  Municipal Utility     Electric  2018.0
# 99   Alabama  City of Dothan  Municipal Utility     Electric  2018.0
# 100  Alabama  City of Dothan  Municipal Utility     Electric  2018.0
#
#         Month  Total Disconnections  Total Reconnenctions  Total Connections  \
# 96    January                1565.0                 932.0            25721.0
# 97   February                2293.0                1430.0            25535.0
# 98      March                1999.0                1292.0            25736.0
# 99      April                2000.0                1239.0            25582.0
# 100       May                1603.0                1013.0            25702.0
#
#      Disconnection Rate
# 96             0.060845
# 97             0.089798
# 98             0.077673
# 99             0.078180
# 100            0.062369

# %% [markdown]
# Calculate the mean disconnection rates for each period across each state to observe state wise trends.
#
# Hypothesis Testing:
#
# ANOVA is used to compare means of disconnection rates between the three periods:
#
# 𝐻0 - The mean disconnection rates are the same across all periods.
#
# 𝐻1 - At least one period has a different mean disconnection rate.

# %% [markdown]
# ## ANOVA

# %%
import pandas as pd
from scipy.stats import f_oneway

# Load the filtered dataset
data = filtered_df2

# Categorize years into periods
def categorize_period(year):
    if year in [2018, 2019]:
        return 'Pre-COVID'
    elif year == 2020:
        return 'COVID'
    elif year in [2021, 2022]:
        return 'Post-COVID'

data['Period'] = data['Year'].apply(categorize_period)

# Group data by State and Period to calculate disconnection rates
state_trends = data.groupby(['State', 'Period'])['Disconnection Rate'].mean().reset_index()

print("Disconnection Rates by State and Period:")
print(state_trends)

# Perform one-way ANOVA for each state
state_results = []

for state in data['State'].unique():
    state_data = data[data['State'] == state]
    pre_covid_rates = state_data[state_data['Period'] == 'Pre-COVID']['Disconnection Rate']
    covid_rates = state_data[state_data['Period'] == 'COVID']['Disconnection Rate']
    post_covid_rates = state_data[state_data['Period'] == 'Post-COVID']['Disconnection Rate']
    
    # Perform ANOVA if there are rates for all periods
    if not (pre_covid_rates.empty or covid_rates.empty or post_covid_rates.empty):
        f_stat, p_value = f_oneway(pre_covid_rates, covid_rates, post_covid_rates)
        state_results.append({
            'State': state,
            'F-statistic': f_stat,
            'P-value': p_value,
            'Significant Difference': 'Yes' if p_value < 0.05 else 'No'
        })

# Convert results to a DataFrame
state_results_df = pd.DataFrame(state_results)

# Display the results
print("\nANOVA Results by State:")
print(state_results_df)
# Out:
# Disconnection Rates by State and Period:
#                State      Period  Disconnection Rate
# 0            Alabama       COVID            0.052214
# 1            Alabama  Post-COVID            0.052646
# 2            Alabama   Pre-COVID            0.075043
# 3         California       COVID            0.001472
# 4         California  Post-COVID            0.000027
# ..               ...         ...                 ...
# 94  Washington, D.C.  Post-COVID            0.000792
# 95  Washington, D.C.   Pre-COVID            0.002457
# 96         Wisconsin       COVID            0.000006
# 97         Wisconsin  Post-COVID            0.001911
# 98         Wisconsin   Pre-COVID            0.001777
#
# [99 rows x 3 columns]
#
# ANOVA Results by State:
#                State  F-statistic       P-value Significant Difference
# 0            Alabama    20.899400  2.960036e-07                    Yes
# 1         California          NaN           NaN                     No
# 2           Colorado          NaN           NaN                     No
# 3        Connecticut          NaN           NaN                     No
# 4            Florida          NaN           NaN                     No
# 5             Hawaii          NaN           NaN                     No
# 6              Idaho          NaN           NaN                     No
# 7           Illinois          NaN           NaN                     No
# 8            Indiana          NaN           NaN                     No
# 9               Iowa     7.976987  4.081468e-04                    Yes
# 10         Louisiana          NaN           NaN                     No
# 11             Maine          NaN           NaN                     No
# 12          Maryland          NaN           NaN                     No
# 13          Michigan          NaN           NaN                     No
# 14         Minnesota          NaN           NaN                     No
# 15          Missouri          NaN           NaN                     No
# 16     New Hampshire          NaN           NaN                     No
# 17        New Jersey          NaN           NaN                     No
# 18          New York          NaN           NaN                     No
# 19    North Carolina          NaN           NaN                     No
# 20      North Dakota          NaN           NaN                     No
# 21              Ohio          NaN           NaN                     No
# 22          Oklahoma          NaN           NaN                     No
# 23            Oregon          NaN           NaN                     No
# 24      Rhode Island          NaN           NaN                     No
# 25    South Carolina    13.305877  2.938190e-06                    Yes
# 26             Texas          NaN           NaN                     No
# 27              Utah          NaN           NaN                     No
# 28           Vermont          NaN           NaN                     No
# 29          Virginia          NaN           NaN                     No
# 30        Washington          NaN           NaN                     No
# 31  Washington, D.C.    15.994342  7.234456e-07                    Yes
# 32         Wisconsin          NaN           NaN                     No
# C:\Users\gokul\AppData\Local\Temp\ipykernel_14032\1783167225.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Period'] = data['Year'].apply(categorize_period)

# %% [markdown]
# Why the Result is NaN:
#
# The dataset contains missing values for disconnection rates in certain rows. When the statistical test encounters missing values, it cannot compute the test statistic properly. If one of the periods (Pre-COVID, COVID, Post-COVID) has no valid data points, the test cannot make a comparison.

# %%
from scipy.stats import f_oneway
import pandas as pd

# Initialize results list
state_results = []

for state in data['State'].unique():
    # Filter data for the current state
    state_data = data[data['State'] == state]
    
    # Extract rates for each period
    pre_covid_rates = state_data[state_data['Period'] == 'Pre-COVID']['Disconnection Rate'].dropna()
    covid_rates = state_data[state_data['Period'] == 'COVID']['Disconnection Rate'].dropna()
    post_covid_rates = state_data[state_data['Period'] == 'Post-COVID']['Disconnection Rate'].dropna()
    
    # Perform ANOVA if there are rates for all periods
    if not (pre_covid_rates.empty or covid_rates.empty or post_covid_rates.empty):
        # Perform ANOVA test
        f_stat, p_value = f_oneway(pre_covid_rates, covid_rates, post_covid_rates)
        
        # Calculate mean rates for each period
        pre_mean = pre_covid_rates.mean()
        covid_mean = covid_rates.mean()
        post_mean = post_covid_rates.mean()
        
        # Determine direction and magnitude of changes (convert to percentages)
        covid_vs_pre = (covid_mean - pre_mean) * 100
        post_vs_covid = (post_mean - covid_mean) * 100
        post_vs_pre = (post_mean - pre_mean) * 100
        
        # Append results to list
        state_results.append({
            'State': state,
            'F-statistic': f_stat,
            'P-value': p_value,
            'Significant Difference': 'Yes' if p_value < 0.05 else 'No',
            'Pre-COVID Mean Disconnection Rate': f"{abs(pre_mean * 100):.4f}%",  # Convert to percentage
            'COVID Mean Disconnection Rate': f"{abs(covid_mean * 100):.4f}%",  # Convert to percentage
            'Post-COVID Mean Disconnection Rate': f"{abs(post_mean * 100):.4f}%",  # Convert to percentage
            'Change COVID vs Pre-COVID': f"{'Increase' if covid_vs_pre > 0 else 'Decrease'} ({abs(covid_vs_pre):.4f}%)",
            'Change Post-COVID vs COVID': f"{'Increase' if post_vs_covid > 0 else 'Decrease'} ({abs(post_vs_covid):.4f}%)",
            'Change Post-COVID vs Pre-COVID': f"{'Increase' if post_vs_pre > 0 else 'Decrease'} ({abs(post_vs_pre):.4f}%)"
        })

# Convert results to a DataFrame
state_results_df = pd.DataFrame(state_results)

# Display the results
print("\nANOVA Results with Period Changes by State:")
print(state_results_df)
# Out:
# ANOVA Results with Period Changes by State:
#                State  F-statistic       P-value Significant Difference  \
# 0            Alabama    20.899400  2.960036e-07                    Yes
# 1         California    21.562746  1.452062e-09                    Yes
# 2           Colorado    19.994920  8.094669e-09                    Yes
# 3        Connecticut    20.035947  1.353850e-08                    Yes
# 4            Florida    41.526804  3.871609e-17                    Yes
# 5              Idaho     2.023592  1.440339e-01                     No
# 6           Illinois    18.550385  1.928506e-08                    Yes
# 7            Indiana    11.949935  9.907891e-06                    Yes
# 8               Iowa     7.976987  4.081468e-04                    Yes
# 9              Maine    27.286522  3.310772e-12                    Yes
# 10          Maryland    45.592240  5.030421e-19                    Yes
# 11          Michigan    53.146239  3.490726e-21                    Yes
# 12         Minnesota    39.728433  9.862991e-17                    Yes
# 13          Missouri     3.072004  4.775985e-02                    Yes
# 14     New Hampshire    13.820550  2.280884e-06                    Yes
# 15        New Jersey    35.716942  5.553879e-09                    Yes
# 16          New York    93.314321  9.610548e-36                    Yes
# 17    North Carolina     2.053981  1.293489e-01                     No
# 18      North Dakota    40.685537  2.268985e-15                    Yes
# 19              Ohio    41.503220  3.337355e-18                    Yes
# 20          Oklahoma     1.239434  2.986476e-01                     No
# 21            Oregon    57.098758  9.052920e-22                    Yes
# 22    South Carolina    13.305877  2.938190e-06                    Yes
# 23             Texas     0.759599  4.702276e-01                     No
# 24              Utah     8.826956  3.404188e-04                    Yes
# 25           Vermont     5.039350  6.775381e-03                    Yes
# 26          Virginia    37.122077  1.132797e-15                    Yes
# 27        Washington    30.924749  6.307391e-13                    Yes
# 28  Washington, D.C.    15.994342  7.234456e-07                    Yes
# 29         Wisconsin     4.360014  1.858731e-02                    Yes
#
#    Pre-COVID Mean Disconnection Rate COVID Mean Disconnection Rate  \
# 0                            7.5043%                       5.2214%
# 1                            0.6378%                       0.1472%
# 2                            0.5095%                       0.1450%
# 3                            0.9787%                       0.1986%
# 4                            2.2871%                       0.7935%
# 5                            1.9136%                       0.8729%
# 6                            0.2104%                       0.1082%
# 7                            0.6931%                       0.3799%
# 8                            0.3898%                       0.1043%
# 9                            0.1827%                       0.0020%
# 10                           0.3897%                       0.0467%
# 11                           1.0391%                       0.1899%
# 12                           0.4641%                       0.0490%
# 13                           1.3653%                       0.7213%
# 14                           0.2273%                       0.0106%
# 15                           2.2273%                       1.7436%
# 16                           0.2043%                       0.0232%
# 17                           0.4377%                       0.4257%
# 18                           0.0222%                       0.0409%
# 19                           0.4571%                       0.1871%
# 20                           0.7906%                       0.5268%
# 21                           0.2561%                       0.0590%
# 22                           0.8493%                       0.4657%
# 23                           1.8449%                       1.6204%
# 24                           0.0234%                       0.3242%
# 25                           0.3315%                       0.1682%
# 26                           0.6515%                       0.0955%
# 27                           0.4707%                       0.0923%
# 28                           0.2457%                       0.0464%
# 29                           0.1777%                       0.0006%
#
#    Post-COVID Mean Disconnection Rate Change COVID vs Pre-COVID  \
# 0                             5.2646%        Decrease (2.2829%)
# 1                             0.0027%        Decrease (0.4906%)
# 2                             0.2243%        Decrease (0.3645%)
# 3                             0.3399%        Decrease (0.7801%)
# 4                             1.3749%        Decrease (1.4935%)
# 5                             1.4007%        Decrease (1.0407%)
# 6                             0.3406%        Decrease (0.1022%)
# 7                             0.5228%        Decrease (0.3132%)
# 8                             0.2906%        Decrease (0.2855%)
# 9                             0.1695%        Decrease (0.1807%)
# 10                            0.1688%        Decrease (0.3431%)
# 11                            0.4094%        Decrease (0.8493%)
# 12                            0.2541%        Decrease (0.4151%)
# 13                            1.1056%        Decrease (0.6439%)
# 14                            0.2261%        Decrease (0.2167%)
# 15                            0.0905%        Decrease (0.4837%)
# 16                            0.0487%        Decrease (0.1812%)
# 17                            0.5679%        Decrease (0.0121%)
# 18                            0.2071%        Increase (0.0188%)
# 19                            0.2851%        Decrease (0.2700%)
# 20                            1.5756%        Decrease (0.2638%)
# 21                            0.1034%        Decrease (0.1971%)
# 22                            0.6778%        Decrease (0.3836%)
# 23                            1.9573%        Decrease (0.2244%)
# 24                            0.1912%        Increase (0.3008%)
# 25                            0.1317%        Decrease (0.1633%)
# 26                            0.3669%        Decrease (0.5560%)
# 27                            0.0685%        Decrease (0.3784%)
# 28                            0.0792%        Decrease (0.1993%)
# 29                            0.1911%        Decrease (0.1772%)
#
#    Change Post-COVID vs COVID Change Post-COVID vs Pre-COVID
# 0          Increase (0.0433%)             Decrease (2.2396%)
# 1          Decrease (0.1445%)             Decrease (0.6351%)
# 2          Increase (0.0793%)             Decrease (0.2852%)
# 3          Increase (0.1413%)             Decrease (0.6388%)
# 4          Increase (0.5814%)             Decrease (0.9121%)
# 5          Increase (0.5278%)             Decrease (0.5129%)
# 6          Increase (0.2324%)             Increase (0.1302%)
# 7          Increase (0.1429%)             Decrease (0.1703%)
# 8          Increase (0.1863%)             Decrease (0.0992%)
# 9          Increase (0.1676%)             Decrease (0.0132%)
# 10         Increase (0.1221%)             Decrease (0.2210%)
# 11         Increase (0.2195%)             Decrease (0.6297%)
# 12         Increase (0.2051%)             Decrease (0.2100%)
# 13         Increase (0.3842%)             Decrease (0.2597%)
# 14         Increase (0.2155%)             Decrease (0.0012%)
# 15         Decrease (1.6531%)             Decrease (2.1368%)
# 16         Increase (0.0256%)             Decrease (0.1556%)
# 17         Increase (0.1423%)             Increase (0.1302%)
# 18         Increase (0.1662%)             Increase (0.1850%)
# 19         Increase (0.0980%)             Decrease (0.1720%)
# 20         Increase (1.0487%)             Increase (0.7849%)
# 21         Increase (0.0445%)             Decrease (0.1527%)
# 22         Increase (0.2121%)             Decrease (0.1714%)
# 23         Increase (0.3369%)             Increase (0.1124%)
# 24         Decrease (0.1331%)             Increase (0.1678%)
# 25         Decrease (0.0365%)             Decrease (0.1998%)
# 26         Increase (0.2714%)             Decrease (0.2845%)
# 27         Decrease (0.0238%)             Decrease (0.4021%)
# 28         Increase (0.0328%)             Decrease (0.1665%)
# 29         Increase (0.1905%)             Increase (0.0133%)

# %% [markdown]
# Given the dataset's characteristics, especially with missing data and potential non-normality in disconnection rates, considered non-parametric hypothesis testing methods as they do not rely on strict assumptions of normality or equal variances.
#
# The p-value is much less than 0.05, so we reject H0(null hypothesis). There is a statistically significant difference in mean disconnection rates between the periods. At least one period has a different mean disconnection rate.
#
# Alternative Method: Kruskal-Wallis H-Test
#
# The Kruskal-Wallis H-test is a non-parametric alternative to ANOVA. It compares the medians of disconnection rates across multiple groups (Pre-COVID, COVID, Post-COVID) without assuming normality.
#
# Why Kruskal-Wallis?
#
# Handles missing data more robustly (after dropping missing values). Compares medians rather than means, which can be more appropriate for skewed data.

# %% [markdown]
# ## Kruskal-Wallis H-Test

# %%
from scipy.stats import kruskal
import pandas as pd

# Initialize results list
state_results = []

for state in data['State'].unique():
    # Filter data for the current state
    state_data = data[data['State'] == state]
    
    # Extract rates for each period
    pre_covid_rates = state_data[state_data['Period'] == 'Pre-COVID']['Disconnection Rate'].dropna()
    covid_rates = state_data[state_data['Period'] == 'COVID']['Disconnection Rate'].dropna()
    post_covid_rates = state_data[state_data['Period'] == 'Post-COVID']['Disconnection Rate'].dropna()
    
    # Perform Kruskal-Wallis test if there are rates for all periods
    if not (pre_covid_rates.empty or covid_rates.empty or post_covid_rates.empty):
        # Perform Kruskal-Wallis test
        h_stat, p_value = kruskal(pre_covid_rates, covid_rates, post_covid_rates)
        
        # Calculate median rates for each period
        pre_median = pre_covid_rates.median()
        covid_median = covid_rates.median()
        post_median = post_covid_rates.median()
        
        # Determine direction and magnitude of changes
        covid_vs_pre = (covid_median - pre_median) * 100
        post_vs_covid = (post_median - covid_median) * 100
        post_vs_pre = (post_median - pre_median) * 100
        
        # Append results to list
        state_results.append({
            'State': state,
            'H-statistic': h_stat,
            'P-value': p_value,
            'Significant Difference': 'Yes' if p_value < 0.05 else 'No',
            'Pre-COVID Median Disconnection Rate': f"{abs(pre_median * 100):.4f}%",
            'COVID Median Disconnection Rate': f"{abs(covid_median * 100):.4f}%",
            'Post-COVID Median Disconnection Rate': f"{abs(post_median * 100):.4f}%",
            'Change COVID vs Pre-COVID': f"{'Increase' if covid_vs_pre > 0 else 'Decrease'} ({abs(covid_vs_pre):.4f}%)",
            'Change Post-COVID vs COVID': f"{'Increase' if post_vs_covid > 0 else 'Decrease'} ({abs(post_vs_covid):.4f}%)",
            'Change Post-COVID vs Pre-COVID': f"{'Increase' if post_vs_pre > 0 else 'Decrease'} ({abs(post_vs_pre):.4f}%)"
        })

# Convert results to a DataFrame
state_results_df = pd.DataFrame(state_results)

# Display the results
print("\nKruskal-Wallis Results with Period Changes by State (Using Medians):")
print(state_results_df)
# Out:
# Kruskal-Wallis Results with Period Changes by State (Using Medians):
#                State  H-statistic       P-value Significant Difference  \
# 0            Alabama    31.850000  1.212999e-07                    Yes
# 1         California   236.950230  3.522990e-52                    Yes
# 2           Colorado    90.990975  1.744058e-20                    Yes
# 3        Connecticut    39.225162  3.036437e-09                    Yes
# 4            Florida    96.210849  1.282566e-21                    Yes
# 5              Idaho     3.748203  1.534928e-01                     No
# 6           Illinois    50.515058  1.073481e-11                    Yes
# 7            Indiana    29.281798  4.380647e-07                    Yes
# 8               Iowa    47.282477  5.404314e-11                    Yes
# 9              Maine   104.442562  2.092116e-23                    Yes
# 10          Maryland   146.703227  1.392512e-32                    Yes
# 11          Michigan    74.777905  5.783412e-17                    Yes
# 12         Minnesota   136.538458  2.244144e-30                    Yes
# 13          Missouri    23.200198  9.165182e-06                    Yes
# 14     New Hampshire    68.821829  1.136396e-15                    Yes
# 15        New Jersey    20.283165  3.940639e-05                    Yes
# 16          New York   288.438624  2.324603e-63                    Yes
# 17    North Carolina    30.195559  2.774071e-07                    Yes
# 18      North Dakota    63.753153  1.432777e-14                    Yes
# 19              Ohio   114.262395  1.542539e-25                    Yes
# 20          Oklahoma     6.387958  4.100838e-02                    Yes
# 21            Oregon    92.239537  9.341980e-21                    Yes
# 22    South Carolina    28.876618  5.364410e-07                    Yes
# 23             Texas     1.109953  5.740857e-01                     No
# 24              Utah     4.228128  1.207463e-01                     No
# 25           Vermont   137.513822  1.378012e-30                    Yes
# 26          Virginia   127.148761  2.454694e-28                    Yes
# 27        Washington    77.133136  1.781363e-17                    Yes
# 28  Washington, D.C.    39.764254  2.319007e-09                    Yes
# 29         Wisconsin     8.650954  1.322724e-02                    Yes
#
#    Pre-COVID Median Disconnection Rate COVID Median Disconnection Rate  \
# 0                              7.6322%                         5.9892%
# 1                              0.2840%                         0.0000%
# 2                              0.3702%                         0.0002%
# 3                              1.0934%                         0.0000%
# 4                              2.2965%                         0.1141%
# 5                              1.7033%                         0.1622%
# 6                              0.1401%                         0.0000%
# 7                              0.6304%                         0.2716%
# 8                              0.1952%                         0.0143%
# 9                              0.0190%                         0.0000%
# 10                             0.3212%                         0.0000%
# 11                             1.1318%                         0.0053%
# 12                             0.3547%                         0.0000%
# 13                             1.0818%                         0.2135%
# 14                             0.1559%                         0.0000%
# 15                             2.3831%                         1.5149%
# 16                             0.1665%                         0.0000%
# 17                             0.3907%                         0.0000%
# 18                             0.0203%                         0.0038%
# 19                             0.3175%                         0.0144%
# 20                             0.8147%                         0.6579%
# 21                             0.2433%                         0.0000%
# 22                             0.8353%                         0.1707%
# 23                             1.7255%                         1.7295%
# 24                             0.0241%                         0.0278%
# 25                             0.2225%                         0.0000%
# 26                             0.4707%                         0.0000%
# 27                             0.3058%                         0.0000%
# 28                             0.2015%                         0.0000%
# 29                             0.1310%                         0.0000%
#
#    Post-COVID Median Disconnection Rate Change COVID vs Pre-COVID  \
# 0                               4.9435%        Decrease (1.6430%)
# 1                               0.0000%        Decrease (0.2840%)
# 2                               0.0571%        Decrease (0.3701%)
# 3                               0.1347%        Decrease (1.0934%)
# 4                               1.0457%        Decrease (2.1824%)
# 5                               1.7664%        Decrease (1.5410%)
# 6                               0.2084%        Decrease (0.1401%)
# 7                               0.3002%        Decrease (0.3588%)
# 8                               0.1280%        Decrease (0.1809%)
# 9                               0.0000%        Decrease (0.0190%)
# 10                              0.0226%        Decrease (0.3212%)
# 11                              0.2744%        Decrease (1.1265%)
# 12                              0.0990%        Decrease (0.3547%)
# 13                              0.4958%        Decrease (0.8683%)
# 14                              0.1487%        Decrease (0.1559%)
# 15                              0.0551%        Decrease (0.8682%)
# 16                              0.0000%        Decrease (0.1665%)
# 17                              0.2542%        Decrease (0.3907%)
# 18                              0.1657%        Decrease (0.0166%)
# 19                              0.1640%        Decrease (0.3031%)
# 20                              0.0257%        Decrease (0.1569%)
# 21                              0.0854%        Decrease (0.2433%)
# 22                              0.7014%        Decrease (0.6646%)
# 23                              2.1761%        Increase (0.0040%)
# 24                              0.0296%        Increase (0.0037%)
# 25                              0.0000%        Decrease (0.2225%)
# 26                              0.0221%        Decrease (0.4707%)
# 27                              0.0000%        Decrease (0.3058%)
# 28                              0.0000%        Decrease (0.2015%)
# 29                              0.0777%        Decrease (0.1310%)
#
#    Change Post-COVID vs COVID Change Post-COVID vs Pre-COVID
# 0          Decrease (1.0457%)             Decrease (2.6887%)
# 1          Decrease (0.0000%)             Decrease (0.2840%)
# 2          Increase (0.0570%)             Decrease (0.3131%)
# 3          Increase (0.1347%)             Decrease (0.9587%)
# 4          Increase (0.9316%)             Decrease (1.2508%)
# 5          Increase (1.6042%)             Increase (0.0632%)
# 6          Increase (0.2084%)             Increase (0.0683%)
# 7          Increase (0.0286%)             Decrease (0.3301%)
# 8          Increase (0.1137%)             Decrease (0.0672%)
# 9          Decrease (0.0000%)             Decrease (0.0190%)
# 10         Increase (0.0226%)             Decrease (0.2986%)
# 11         Increase (0.2691%)             Decrease (0.8574%)
# 12         Increase (0.0990%)             Decrease (0.2557%)
# 13         Increase (0.2823%)             Decrease (0.5859%)
# 14         Increase (0.1487%)             Decrease (0.0071%)
# 15         Decrease (1.4598%)             Decrease (2.3280%)
# 16         Decrease (0.0000%)             Decrease (0.1665%)
# 17         Increase (0.2542%)             Decrease (0.1364%)
# 18         Increase (0.1620%)             Increase (0.1454%)
# 19         Increase (0.1496%)             Decrease (0.1535%)
# 20         Decrease (0.6322%)             Decrease (0.7891%)
# 21         Increase (0.0854%)             Decrease (0.1579%)
# 22         Increase (0.5307%)             Decrease (0.1339%)
# 23         Increase (0.4466%)             Increase (0.4506%)
# 24         Increase (0.0017%)             Increase (0.0055%)
# 25         Decrease (0.0000%)             Decrease (0.2225%)
# 26         Increase (0.0221%)             Decrease (0.4486%)
# 27         Decrease (0.0000%)             Decrease (0.3058%)
# 28         Decrease (0.0000%)             Decrease (0.2015%)
# 29         Increase (0.0777%)             Decrease (0.0532%)

# %% [markdown]
# ## T-Test for comparison between Pre and Post Covid Periods

# %%
from scipy.stats import ttest_ind
import pandas as pd

# Initialize results list
state_results = []

for state in data['State'].unique():
    # Filter data for the current state
    state_data = data[data['State'] == state]
    
    # Extract rates for Pre-COVID and Post-COVID periods
    pre_covid_rates = state_data[state_data['Period'] == 'Pre-COVID']['Disconnection Rate'].dropna()
    post_covid_rates = state_data[state_data['Period'] == 'Post-COVID']['Disconnection Rate'].dropna()
    
    # Perform t-test if there are rates for both periods
    if not (pre_covid_rates.empty or post_covid_rates.empty):
        # Perform t-test
        t_stat, p_value = ttest_ind(pre_covid_rates, post_covid_rates, equal_var=False)  # Use Welch's t-test if variances are not equal
        
        # Calculate mean rates for each period
        pre_mean = pre_covid_rates.mean()
        post_mean = post_covid_rates.mean()
        
        # Determine direction and magnitude of changes
        post_vs_pre = (post_mean - pre_mean) * 100
        
        # Append results to list
        state_results.append({
            'State': state,
            'T-statistic': t_stat,
            'P-value': p_value,
            'Significant Difference': 'Yes' if p_value < 0.05 else 'No',
            'Pre-COVID Mean Disconnection Rate': f"{abs(pre_mean * 100):.4f}%",
            'Post-COVID Mean Disconnection Rate': f"{abs(post_mean * 100):.4f}%",
            'Change Post-COVID vs Pre-COVID': f"{'Increase' if post_vs_pre > 0 else 'Decrease'} ({abs(post_vs_pre):.4f}%)"
        })

# Convert results to a DataFrame
state_results_df = pd.DataFrame(state_results)

# Display the results
print("\nT-Test Results for Post-COVID vs Pre-COVID by State:")
print(state_results_df)
# Out:
# T-Test Results for Post-COVID vs Pre-COVID by State:
#                State  T-statistic       P-value Significant Difference  \
# 0            Alabama     8.794306  2.736442e-10                    Yes
# 1         California     7.133998  3.307336e-11                    Yes
# 2           Colorado     4.831610  2.707788e-06                    Yes
# 3        Connecticut     4.148093  2.926454e-04                    Yes
# 4            Florida     5.697210  3.256112e-08                    Yes
# 5             Hawaii    -1.247863  2.431035e-01                     No
# 6              Idaho     1.167505  2.506881e-01                     No
# 7           Illinois    -4.261961  2.644405e-05                    Yes
# 8            Indiana     2.897871  4.131622e-03                    Yes
# 9               Iowa     1.627542  1.047290e-01                     No
# 10             Maine     0.559736  5.758477e-01                     No
# 11          Maryland     6.376917  4.788028e-10                    Yes
# 12          Michigan     6.020202  1.366427e-07                    Yes
# 13         Minnesota     4.583847  1.097041e-05                    Yes
# 14          Missouri     0.944351  3.471963e-01                     No
# 15     New Hampshire     0.024322  9.806501e-01                     No
# 16        New Jersey    14.004178  2.784562e-13                    Yes
# 17          New York    10.599551  2.112772e-23                    Yes
# 18    North Carolina    -1.988980  4.778142e-02                    Yes
# 19      North Dakota   -10.253833  4.195054e-17                    Yes
# 20              Ohio     6.281608  5.215155e-10                    Yes
# 21          Oklahoma    -0.886303  3.903364e-01                     No
# 22            Oregon     8.080497  1.654923e-13                    Yes
# 23    South Carolina     3.010690  2.898500e-03                    Yes
# 24             Texas    -0.529971  5.976991e-01                     No
# 25              Utah    -4.120318  2.114011e-04                    Yes
# 26           Vermont     6.520893  2.483387e-10                    Yes
# 27          Virginia     4.708308  3.553631e-06                    Yes
# 28        Washington     6.434891  1.921036e-09                    Yes
# 29  Washington, D.C.     4.504154  1.987521e-05                    Yes
# 30         Wisconsin    -0.174397  8.632112e-01                     No
#
#    Pre-COVID Mean Disconnection Rate Post-COVID Mean Disconnection Rate  \
# 0                            7.5043%                            5.2646%
# 1                            0.6378%                            0.0027%
# 2                            0.5095%                            0.2243%
# 3                            0.9787%                            0.3399%
# 4                            2.2871%                            1.3749%
# 5                            0.1057%                            0.1356%
# 6                            1.9136%                            1.4007%
# 7                            0.2104%                            0.3406%
# 8                            0.6931%                            0.5228%
# 9                            0.3898%                            0.2906%
# 10                           0.1827%                            0.1695%
# 11                           0.3897%                            0.1688%
# 12                           1.0391%                            0.4094%
# 13                           0.4641%                            0.2541%
# 14                           1.3653%                            1.1056%
# 15                           0.2273%                            0.2261%
# 16                           2.2273%                            0.0905%
# 17                           0.2043%                            0.0487%
# 18                           0.4377%                            0.5679%
# 19                           0.0222%                            0.2071%
# 20                           0.4571%                            0.2851%
# 21                           0.7906%                            1.5756%
# 22                           0.2561%                            0.1034%
# 23                           0.8493%                            0.6778%
# 24                           1.8449%                            1.9573%
# 25                           0.0234%                            0.1912%
# 26                           0.3315%                            0.1317%
# 27                           0.6515%                            0.3669%
# 28                           0.4707%                            0.0685%
# 29                           0.2457%                            0.0792%
# 30                           0.1777%                            0.1911%
#
#    Change Post-COVID vs Pre-COVID
# 0              Decrease (2.2396%)
# 1              Decrease (0.6351%)
# 2              Decrease (0.2852%)
# 3              Decrease (0.6388%)
# 4              Decrease (0.9121%)
# 5              Increase (0.0299%)
# 6              Decrease (0.5129%)
# 7              Increase (0.1302%)
# 8              Decrease (0.1703%)
# 9              Decrease (0.0992%)
# 10             Decrease (0.0132%)
# 11             Decrease (0.2210%)
# 12             Decrease (0.6297%)
# 13             Decrease (0.2100%)
# 14             Decrease (0.2597%)
# 15             Decrease (0.0012%)
# 16             Decrease (2.1368%)
# 17             Decrease (0.1556%)
# 18             Increase (0.1302%)
# 19             Increase (0.1850%)
# 20             Decrease (0.1720%)
# 21             Increase (0.7849%)
# 22             Decrease (0.1527%)
# 23             Decrease (0.1714%)
# 24             Increase (0.1124%)
# 25             Increase (0.1678%)
# 26             Decrease (0.1998%)
# 27             Decrease (0.2845%)
# 28             Decrease (0.4021%)
# 29             Decrease (0.1665%)
# 30             Increase (0.0133%)

# %% [markdown]
# At least one of the periods has a significantly different median disconnection rate compared to the others. This does not specify which periods differ; it only indicates that a difference exists.
#
# We reject null hypothesis here. At least one period has a different median disconnection rate.
#
# Next Steps:
#
# Perform post-hoc pairwise comparisons to determine which periods (Pre-COVID vs COVID, COVID vs Post-COVID, etc.) differ from each other.
#
# Dunn’s Test is commonly used for post-hoc pairwise comparisons after Kruskal-Wallis. It adjusts for multiple comparisons to control the family-wise error rate.

# %% [markdown]
# ## Dunn’s Test

# %%
pip install scikit-posthocs
# Out:
# Requirement already satisfied: scikit-posthocs in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (0.8.1)
# Requirement already satisfied: numpy in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from scikit-posthocs) (1.24.3)
# Requirement already satisfied: scipy in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from scikit-posthocs) (1.10.1)
# Requirement already satisfied: statsmodels in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from scikit-posthocs) (0.14.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from scikit-posthocs) (2.0.3)
# Requirement already satisfied: seaborn in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from scikit-posthocs) (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from scikit-posthocs) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from pandas>=0.20.0->scikit-posthocs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from pandas>=0.20.0->scikit-posthocs) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from pandas>=0.20.0->scikit-posthocs) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (10.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from matplotlib->scikit-posthocs) (6.4.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from statsmodels->scikit-posthocs) (1.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->scikit-posthocs) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\gokul\anaconda3\envs\dviz\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->scikit-posthocs) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import scikit_posthocs as sp
import numpy as np

# Perform Dunn's test for each state
state_dunn_results = {}

for state in data['State'].unique():
    # Filter data for the current state
    state_data = data[data['State'] == state]
    
    # Drop NaN values for each period
    pre_covid_rates = state_data[state_data['Period'] == 'Pre-COVID']['Disconnection Rate'].dropna()
    covid_rates = state_data[state_data['Period'] == 'COVID']['Disconnection Rate'].dropna()
    post_covid_rates = state_data[state_data['Period'] == 'Post-COVID']['Disconnection Rate'].dropna()
    
    # Check if all periods have data
    if len(pre_covid_rates) > 0 and len(covid_rates) > 0 and len(post_covid_rates) > 0:
        # Combine the data into one array
        all_rates = np.concatenate([pre_covid_rates, covid_rates, post_covid_rates])
        
        # Create a corresponding array of group labels
        groups = (
            ['Pre-COVID'] * len(pre_covid_rates) +
            ['COVID'] * len(covid_rates) +
            ['Post-COVID'] * len(post_covid_rates)
        )
        
        # Create a DataFrame for Dunn's test
        df = pd.DataFrame({
            'Disconnection Rate': all_rates,
            'Period': groups
        })
        
        # Run Dunn's test
        dunn_results = sp.posthoc_dunn(df, val_col='Disconnection Rate', group_col='Period', p_adjust='bonferroni')
        
        # Store the results
        state_dunn_results[state] = dunn_results

# Display results for each state
for state, results in state_dunn_results.items():
    print(f"\nDunn's Test Results for {state}:")
    print(results)
# Out:
# Dunn's Test Results for Alabama:
#                COVID    Post-COVID     Pre-COVID
# COVID       1.000000  9.042277e-01  4.829161e-04
# Post-COVID  0.904228  1.000000e+00  4.105921e-07
# Pre-COVID   0.000483  4.105921e-07  1.000000e+00
#
# Dunn's Test Results for California:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  8.200807e-02  1.194004e-23
# Post-COVID  8.200807e-02  1.000000e+00  2.001470e-47
# Pre-COVID   1.194004e-23  2.001470e-47  1.000000e+00
#
# Dunn's Test Results for Colorado:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  3.758817e-03  1.728064e-19
# Post-COVID  3.758817e-03  1.000000e+00  2.489778e-11
# Pre-COVID   1.728064e-19  2.489778e-11  1.000000e+00
#
# Dunn's Test Results for Connecticut:
#                    COVID  Post-COVID     Pre-COVID
# COVID       1.000000e+00    0.003707  1.163413e-09
# Post-COVID  3.707018e-03    1.000000  2.115444e-05
# Pre-COVID   1.163413e-09    0.000021  1.000000e+00
#
# Dunn's Test Results for Florida:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.557925e-06  3.100096e-22
# Post-COVID  2.557925e-06  1.000000e+00  2.921256e-07
# Pre-COVID   3.100096e-22  2.921256e-07  1.000000e+00
#
# Dunn's Test Results for Idaho:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000    0.604559   0.158699
# Post-COVID  0.604559    1.000000   1.000000
# Pre-COVID   0.158699    1.000000   1.000000
#
# Dunn's Test Results for Illinois:
#                    COVID    Post-COVID  Pre-COVID
# COVID       1.000000e+00  3.607306e-12   0.000002
# Post-COVID  3.607306e-12  1.000000e+00   0.218200
# Pre-COVID   1.685633e-06  2.181995e-01   1.000000
#
# Dunn's Test Results for Indiana:
#                    COVID  Post-COVID     Pre-COVID
# COVID       1.000000e+00    0.059382  2.469336e-07
# Post-COVID  5.938246e-02    1.000000  1.350990e-03
# Pre-COVID   2.469336e-07    0.001351  1.000000e+00
#
# Dunn's Test Results for Iowa:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.596962e-07  2.776477e-11
# Post-COVID  2.596962e-07  1.000000e+00  2.101896e-01
# Pre-COVID   2.776477e-11  2.101896e-01  1.000000e+00
#
# Dunn's Test Results for Maine:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.993989e-17  1.904323e-22
# Post-COVID  2.993989e-17  1.000000e+00  1.979922e-01
# Pre-COVID   1.904323e-22  1.979922e-01  1.000000e+00
#
# Dunn's Test Results for Maryland:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  1.199325e-05  1.806961e-29
# Post-COVID  1.199325e-05  1.000000e+00  1.437131e-16
# Pre-COVID   1.806961e-29  1.437131e-16  1.000000e+00
#
# Dunn's Test Results for Michigan:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.725082e-09  7.573140e-16
# Post-COVID  2.725082e-09  1.000000e+00  2.008355e-05
# Pre-COVID   7.573140e-16  2.008355e-05  1.000000e+00
#
# Dunn's Test Results for Minnesota:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  7.789525e-15  3.837722e-30
# Post-COVID  7.789525e-15  1.000000e+00  4.287676e-10
# Pre-COVID   3.837722e-30  4.287676e-10  1.000000e+00
#
# Dunn's Test Results for Missouri:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000    0.001150   0.000015
# Post-COVID  0.001150    1.000000   0.169871
# Pre-COVID   0.000015    0.169871   1.000000
#
# Dunn's Test Results for New Hampshire:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  3.666544e-11  4.734092e-15
# Post-COVID  3.666544e-11  1.000000e+00  1.000000e+00
# Pre-COVID   4.734092e-15  1.000000e+00  1.000000e+00
#
# Dunn's Test Results for New Jersey:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000    0.137194    1.00000
# Post-COVID  0.137194    1.000000    0.00002
# Pre-COVID   1.000000    0.000020    1.00000
#
# Dunn's Test Results for New York:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  9.741380e-01  8.842589e-41
# Post-COVID  9.741380e-01  1.000000e+00  1.092734e-51
# Pre-COVID   8.842589e-41  1.092734e-51  1.000000e+00
#
# Dunn's Test Results for North Carolina:
#                    COVID  Post-COVID     Pre-COVID
# COVID       1.000000e+00    0.000102  1.598675e-07
# Post-COVID  1.018318e-04    1.000000  3.440671e-01
# Pre-COVID   1.598675e-07    0.344067  1.000000e+00
#
# Dunn's Test Results for North Dakota:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.344490e-12  7.675873e-01
# Post-COVID  2.344490e-12  1.000000e+00  4.701026e-08
# Pre-COVID   7.675873e-01  4.701026e-08  1.000000e+00
#
# Dunn's Test Results for Ohio:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.726504e-08  1.276904e-25
# Post-COVID  2.726504e-08  1.000000e+00  1.709520e-08
# Pre-COVID   1.276904e-25  1.709520e-08  1.000000e+00
#
# Dunn's Test Results for Oklahoma:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000     1.00000   0.181089
# Post-COVID  1.000000     1.00000   0.073030
# Pre-COVID   0.181089     0.07303   1.000000
#
# Dunn's Test Results for Oregon:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  8.552612e-04  2.283210e-19
# Post-COVID  8.552612e-04  1.000000e+00  9.913568e-12
# Pre-COVID   2.283210e-19  9.913568e-12  1.000000e+00
#
# Dunn's Test Results for South Carolina:
#                    COVID  Post-COVID     Pre-COVID
# COVID       1.000000e+00    0.002472  2.417422e-07
# Post-COVID  2.472463e-03    1.000000  3.857488e-02
# Pre-COVID   2.417422e-07    0.038575  1.000000e+00
#
# Dunn's Test Results for Texas:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000    0.903296        1.0
# Post-COVID  0.903296    1.000000        1.0
# Pre-COVID   1.000000    1.000000        1.0
#
# Dunn's Test Results for Utah:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000    1.000000   0.177227
# Post-COVID  1.000000    1.000000   0.260566
# Pre-COVID   0.177227    0.260566   1.000000
#
# Dunn's Test Results for Vermont:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  1.652973e-03  2.021457e-26
# Post-COVID  1.652973e-03  1.000000e+00  5.657390e-19
# Pre-COVID   2.021457e-26  5.657390e-19  1.000000e+00
#
# Dunn's Test Results for Virginia:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  2.110038e-05  1.747584e-26
# Post-COVID  2.110038e-05  1.000000e+00  2.704853e-13
# Pre-COVID   1.747584e-26  2.704853e-13  1.000000e+00
#
# Dunn's Test Results for Washington:
#                    COVID    Post-COVID     Pre-COVID
# COVID       1.000000e+00  1.000000e+00  1.096894e-10
# Post-COVID  1.000000e+00  1.000000e+00  1.240225e-15
# Pre-COVID   1.096894e-10  1.240225e-15  1.000000e+00
#
# Dunn's Test Results for Washington, D.C.:
#                COVID    Post-COVID     Pre-COVID
# COVID       1.000000  1.000000e+00  1.214953e-06
# Post-COVID  1.000000  1.000000e+00  1.168770e-07
# Pre-COVID   0.000001  1.168770e-07  1.000000e+00
#
# Dunn's Test Results for Wisconsin:
#                COVID  Post-COVID  Pre-COVID
# COVID       1.000000    0.051954   0.016049
# Post-COVID  0.051954    1.000000   1.000000
# Pre-COVID   0.016049    1.000000   1.000000

# %% [markdown]
# States like California, New York, and Michigan exhibited significant differences across all pairwise comparisons, especially between Pre-COVID and Post-COVID/COVID periods, suggesting substantial shifts in disconnection rates during the pandemic. Conversely, states such as Texas, Idaho, and Utah showed no significant pairwise differences, reinforcing the conclusion that their disconnection rates remained consistent across the three periods.
